# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# <b>Objectives:</b>
#
# <ul>
#     <li>Learning and internalizing the tools in data science.</li>
#     <li>Familiriazing oneself with IDEs.</li>
#     <li>Understanding the use of oipen source code management platofrms.</li>
#  </ul>

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# <ol>
#     <li>Python</li>
#     <li>SQL</li>
#     <li>R</li>
# </

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. TensorFlow
# 2. Scikit-Learn
# 3. Pandas
# 4. Pandas

# %% [markdown]
# Data Science Tools:
# <ol>
#     <li>Jupyter Notebook</li>
#     <li>Spyder</li>
#     <li>Google Colab</li>
#  </ol>

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
This a simple arithmetic expression to mutiply then add integers:

# %%
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60
def converToHours(min):
    hours = min // 60
    minutes = min % 60
    final_hour= str(hours) + 'hrs:' + str(minutes) + 'mins'
    return final_hour

print(converToHours(200))
# Out:
# 3hrs:20mins

# %% [markdown]
# # Author
#
# Quwamdeen Oloyede
